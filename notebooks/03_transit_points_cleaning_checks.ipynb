# %%
from pathlib import Path
import geopandas as gpd

# %%
BASE_DIR = Path.cwd().parent
CLEAN_DIR = BASE_DIR / "data" / "clean"

path = CLEAN_DIR / "grid_250m_with_pedestrian_and_transit.gpkg"

g = gpd.read_file(path, layer="grid_ped_transit")

g[["transit_stops_count"]].describe(), (g["transit_stops_count"] > 0).sum(), g["transit_stops_count"].sum()
# Out:
# (       transit_stops_count
#  count         25024.000000
#  mean              0.369405
#  std               1.009629
#  min               0.000000
#  25%               0.000000
#  50%               0.000000
#  75%               0.000000
#  max              17.000000,
#  4046,
#  9244)
